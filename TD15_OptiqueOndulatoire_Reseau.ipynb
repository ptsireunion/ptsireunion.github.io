# %% [markdown]
# ![WeTheGeeksV3.jpg](https://raw.githubusercontent.com/ptsireunion/CPGE-PT-Reunion/main/WeTheGeeksV3.jpg)
#
# <div class="alert alert-block alert-info">
#     <b> PYTHON – Travaux Dirigés N°15
# </div>
#
# # Optique ondulatoire - Spectroscope à réseau
# >Physique Chimie `CPGE PT` lien vers le blog <a> https://cpge-reunion-ptsi.blogspot.com/p/python_6.html </a>
#     >> Sujet inspiré par diverses lectures sur le net. Merci à leurs contributeurs.trices

# %% [markdown]
# Dans ce notebook, on va `caractériser un réseau` en `déterminant son nombre de traits par mm`. On cherchera en particulier à obtenir la pente d'une courbe à l'aide d'une `régression linéaire` et d'une `simulation Monte Carlo` permettant par la simulation d'évaluer les incertitudes de mesure.

# %% [markdown]
# # Théorie / protocole

# %% [markdown]
# > **Question 1** :
# > On donne le pas $a$ du réseau et $\lambda$ la longueur d'onde émise par la source. On appelle $k$ l'ordre observé. Rappeler la formule des réseaux en respectant les notations. Que devient cette formule pour l'ordre $1$ si le réseau est éclairé en incidence normale ?

# %% [markdown]
# > **Question 2** :
# > Le réseau est caractérisé par son pas $a$ ou de manière équivalente par la fréquence spatiale $n$ c'est-à-dire le **nombre de traits par mm**. Donner le lien entre les deux grandeurs.

# %% [markdown]
# > **Question 3** :
# > 	On appelle $i$ l'angle de transmission du réseau, $j$ l'angle d'incidence, $\alpha_0$ et $\alpha_1$ les positions angulaires correspondant respectivement à l'ordre nul et à l'ordre 1 en incidence normale. Exprimer $i$ et $j$ pour l'ordre 1 en incidence normale en fonction des données utiles.
# >> On donne un schéma symbolique du réseau dans un cas quelconque :
# >> ![ReseauDiffraction.png](https://raw.githubusercontent.com/ptsireunion/CPGE-PT-Reunion/main/ReseauDiffraction.png)

# %% [markdown]
# On éclaire un réseau de $(550traits/mm)$ avec une lampe spectrale Hg dont les raies $\lambda$ sont connues et on mesure les angles $i$ des ordres $1$ pour chaque raie :
#
# **Données : les principales raies du mercure Hg**
#
# |couleur             |violet|violet|indigo|bleu-vert| vert |jaune |jaune |rouge |
# |:------------------:|:----:|:----:|:----:|:-------:|:----:|:----:|:----:|:----:|
# |longueur d'onde $\lambda$ (nm)|404.8 |407.8 |435.8 |491.6    |546.1 |576.9 |579.1   |623.4 |
# |angle $i$(degré)    |12.688|12.988|13.738|15.488   |17.121|18.055|18.155|19.538|

# %% [markdown]
# > **Question 4** :
# > 	Expliquer comment ces données permettent d'en déduire le pas du réseau à l'aide d'une fonction linéaire à définir à partir des variables $i$ et $\lambda$. On appellera cette courbe **'courbe d'étalonnage'**. Comment, une fois représentée, pourra t'elle servir à des mesures de spectrométrie ?

# %% [markdown]
# # Incertitudes
#
# On modélise $\sin(i)$ en fonction de $\lambda$ par une droite en effectuant une régression linéaire. On n'évaluera que l'incertitude sur l'ordonnée, celle sur l'abscisse $\lambda$ étant négligée.
#
# L'incertitude-type de lecture $u(i)$ sur $i$ (type B) est de $10'$=10 minute d'arc. On rappelle que $1'=\frac{1}{60}°$ donc $u(i)=10'$

# %% [markdown]
# > **Question 5** :
# > 	Evaluer l'incertitude-type de lecture $u(i)$ sur $i$. On admet que si on connait l'incertitude type $u_x$ sur $x$ alors la formule de propagation des incertitudes nous donne celle de la fonction $f(x)=sin(x)$ soit $u_f=u_x.cos(x)$. En déduire l'expression théorique de l'incertitude type sur l'ordonnée

# %% [markdown]
# # Codage

# %% [markdown]
# > **Question 6** :
# > Terminez le code ci-dessous qui permet de représenter la courbe d'étalonnage à l'aide de la fonction `polyfit`.
# > >Vous lirez d'abord ici https://xofe14.scenari-community.org/Publications/Formations/0_Boite_a_outils_Python_web/co/polyfit.html des informations sur la fonction `polyfit`.
# >  Pour représenter les barres d'erreur vous lirez : https://www.python-simple.com/python-matplotlib/errorBars.php pour vous inspirer de la fonction `errorbar`

# %%
## Importation des bibliothèques utiles
import numpy as np
import numpy.random as rd
import matplotlib.pyplot as plt

#Saisies des données expérimentales
lamb=np.array([404.8, 407.8, 435.8, 491.6, 546.1, 576.9, 579.1, 623.4]) #longueur d'onde en nm (lambda mot-clé pour fonction).
i=(np.pi/180)*np.array([12.688, 12.988, 13.738, 15.488, 17.121, 18.055, 18.155, 19.538]) #angle transmis converti en radian.
u_i=......................... #incertitude-type sur l'angle i (3') en radian.
y=...........................
u_y=.....................................................
p=np.polyfit(...................................) #calcul des paramètres d'ajustement affine

# Représentation graphique              
plt.plot(.........................................,label='modèle affine') 

plt.errorbar(........................................,label="Données expérimentales")# représentation des points expérimentaux avec barres d'incertitude à \pm u

plt.xlim(400,650), plt.xlabel("Longueur d'onde (en nm)")                   #axe des abscisses
plt.ylim(0.20,0.40), plt.ylabel("sin(i)")    #axe des ordonnées
plt.legend() 
plt.title("Courbe d'étalonnage réalisée par la source Hg")
plt.grid()
# Out:
#   Cell In[19], line 9
#     u_i=......................... #incertitude-type sur l'angle i (3') en radian.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# > **Question 7** :
# > Pour finalement afficher la valeur du nombre de traits/mm $n$ avec son incertitude type $u(n)$, on va simuler 10000 fois la mesure précédentes par la méthode de Monte Carlo avec une distribution statistique uniforme autour des valeurs $y$ en ordonnée. La moyenne et l'écart-type des mesures de pente nous permettront d'obtenir les valeurs recherchées. On fera également le calcul pour l'ordonnée à l'origine.

# %%
## Simulation Monte-Carlo où on ajoute à y du bruit déterminé par son incertitude-type.
#On obtient un ensemble de droites. 
#On fait la moyenne des pentes et l'écart-type donne l'incertitude-type sur la pente.

NMC = 50000                           # nombre d'expériences simulées
aMC, bMC = [], []                     # initialisation des listes dans lesquelles on va stocker
                                      # les valeurs de la pente a et de l'ordonnée à l'orignine et b correspondant à chaque expérience simulée


for i in range(NMC):                  # pour chaque expérience
  # on simule la mesure des y pour les 8 longueurs d'onde
  yMC = ..................................
  # on reprend l'ajustement affine avec cette série de valeurs de y
  p = np.polyfit(....................................1)
  # on stocke les valeurs des paramètres d'ajustement dans les listes aMC et bMC
  aMC.append(........................) #pente
  bMC.append(........................) #ordonnée à l'origine
    
## Représentation graphique de l'ensemble des valeurs de a et de b obtenues sous forme d'histogrammes

plt.figure(figsize = (15, 4))
plt.subplot(1, 2, 1)
plt.hist(..................................)
plt.xlabel(r"Valeurs de la pente $a$ obtenues")
plt.ylabel(r"Nombre d'apparitions")
plt.subplot(1, 2, 2)
plt.hist(.................................)
plt.xlabel(r"Valeurs de l'ordonnée à l'origine $b$ obtenues")
plt.ylabel(r"Nombre d'apparitions")

## Analyse statistique de l'ensemble des valeurs de a et de b obtenues

amoy = ............................................
u_a = ...............................................
print("Estimation du nombre de traits par mm n :")
print("* Valeur mesurée : n = {}".format(amoy))
print("* Incertitude-type : u(n) = {}\n".format(u_a))

bmoy = ....................................................
u_b = ....................................................
print("Estimation du paramètre ordonnée à l'origine :")
print("* Valeur mesurée : b = {}".format(bmoy))
print("* Incertitude-type : u(b) = {}".format(u_b))
# Out:
#   Cell In[20], line 12
#     yMC = ..................................
#              ^
# SyntaxError: invalid syntax
